# %%
import pandas as pd
import numpy as np
import torch
import torchvision
import os

# %%
os.listdir('../')
# Out:
# ['zips',
#  'EAD2020-Phase-II-Detection_Segmentation-99Frames',
#  'ead2020_semantic_segmentation',
#  'EAD2020_dataType_framesOnly',
#  'notebooks',
#  'EAD2020-Phase-II_dataType_sequence']

# %%
os.chdir('../EAD2020_dataType_framesOnly')

# %%
os.listdir()
# Out:
# ['EAD2020_frameOnly_01110.txt',
#  'EAD2020_frameOnly_01955.txt',
#  'EAD2020_frameOnly_00326.txt',
#  'EAD2020_frameOnly_01256.txt',
#  'EAD2020_frameOnly_00578.txt',
#  'EAD2020_frameOnly_01701.txt',
#  'EAD2020_frameOnly_02039.txt',
#  'EAD2020_frameOnly_00793.txt',
#  'EAD2020_frameOnly_02172.txt',
#  'EAD2020_frameOnly_00970.txt',
#  'EAD2020_frameOnly_00184.txt',
#  'EAD2020_frameOnly_00689.txt',
#  'EAD2020_frameOnly_00399.txt',
#  'EAD2020_frameOnly_01839.txt',
#  'EAD2020_frameOnly_00019.txt',
#  'EAD2020_frameOnly_00878.txt',
#  'EAD2020_frameOnly_00610.txt',
#  'EAD2020_frameOnly_01230.txt',
#  'EAD2020_frameOnly_01849.txt',
#  'EAD2020_frameOnly_01154.txt',
#  'EAD2020_frameOnly_01052.txt',
#  'EAD2020_frameOnly_00033.txt',
#  'EAD2020_frameOnly_00763.txt',
#  'EAD2020_frameOnly_00202.txt',
#  'EAD2020_frameOnly_01574.txt',
#  'EAD2020_frameOnly_01399.txt',
#  'EAD2020_frameOnly_01775.txt',
#  'EAD2020_frameOnly_01319.txt',
#  'EAD2020_frameOnly_00639.txt',
# ...

# %%
os.chdir('gt_bbox/')

# %%
pwd
# Out:
# '/home/nikamanth/Documents/endocv/EAD2020_dataType_framesOnly/EAD2020_dataType_framesOnly/gt_bbox'

# %%
os.chdir('/home/nikamanth/Documents/endocv/repos/PyTorch-YOLOv3/data/custom/images/')

# %%
images = os.listdir()

# %%
len(images)
# Out:
# 2200

# %%
train = images[:2000]

# %%
val = images[2000:]

# %%
len(train)
# Out:
# 2000

# %%
len(val)
# Out:
# 200

# %%
val
# Out:
# ['EAD2020_frameOnly_00724.jpg',
#  'EAD2020_frameOnly_00563.jpg',
#  'EAD2020_frameOnly_00278.jpg',
#  'EAD2020_frameOnly_00110.jpg',
#  'EAD2020_frameOnly_01114.jpg',
#  'EAD2020_frameOnly_01773.jpg',
#  'EAD2020_frameOnly_01949.jpg',
#  'EAD2020_frameOnly_01770.jpg',
#  'EAD2020_frameOnly_00564.jpg',
#  'EAD2020_frameOnly_00206.jpg',
#  'EAD2020_frameOnly_01073.jpg',
#  'EAD2020_frameOnly_01417.jpg',
#  'EAD2020_frameOnly_00317.jpg',
#  'EAD2020_frameOnly_00955.jpg',
#  'EAD2020_frameOnly_01435.jpg',
#  'EAD2020_frameOnly_01550.jpg',
#  'EAD2020_frameOnly_01443.jpg',
#  'EAD2020_frameOnly_01985.jpg',
#  'EAD2020_frameOnly_00318.jpg',
#  'EAD2020_frameOnly_01239.jpg',
#  'EAD2020_frameOnly_01635.jpg',
#  'EAD2020_frameOnly_01380.jpg',
#  'EAD2020_frameOnly_01067.jpg',
#  'EAD2020_frameOnly_00327.jpg',
#  'EAD2020_frameOnly_00293.jpg',
#  'EAD2020_frameOnly_01455.jpg',
#  'EAD2020_frameOnly_01820.jpg',
#  'EAD2020_frameOnly_01465.jpg',
#  'EAD2020_frameOnly_00100.jpg',
# ...

# %%
pwd
# Out:
# '/home/nikamanth/Documents/endocv/repos/PyTorch-YOLOv3/data/custom/images'

# %%
f = open("demofile1.txt", "a+")

# %%
f = open("demo1.txt",'a+')
for i in train:
    f.write('/home/nikamanth/Documents/endocv/repos/PyTorch-YOLOv3/data/custom/'+i+'\n')
