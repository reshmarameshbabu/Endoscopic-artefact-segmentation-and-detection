# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pwd
# Out:
# '/content'

# %%
def rotateImage(image, angle):
  image_center = tuple(np.array(image.shape[1::-1]) / 2)
  rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
  result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
  return result

# %%
l=[]
for i in os.listdir('/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/images_ead2020'):
    l.append(i)
l.sort()
for i in l:
    print(i)
    im = cv2.imread('/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/images_ead2020/'+i)
    # print(len(im))
    
    im2 = cv2.flip(im, 0) #vertical
    #im3 = rot30 = rotateImage( im, 30 )
    im4 = cv2.rotate(im, cv2.ROTATE_90_CLOCKWISE)
    im5 = cv2.rotate(im, cv2.ROTATE_180)
    print(len(im2))
    #rot30 = rotateImage( im, 30 )
    #rot60 = rotateImage( im, 60 )
    #rot45 = rotateImage( im, 45 )
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_1.png',im)
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_2.png',im2)
    #cv2.imwrite('/content/drive/My Drive/mini/augment/output'+str(i)+'_3.png',im3)
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_4.png',im4)
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_5.png',im5)
    #cv2.imwrite('/home/nikamanth/Documents/map/train_rot/output/out'+str(i)+'_6.png',rot30)
    #cv2.imwrite('/home/nikamanth/Documents/map/train_rot/output/out'+str(i)+'_7.png',rot60)
    #cv2.imwrite('/home/nikamanth/Documents/map/train_rot/output/out'+str(i)+'_8.png',rot45)
# Out:
# EAD2020_semantic_00000.jpg
# 499
# EAD2020_semantic_00001.jpg
# 1079
# EAD2020_semantic_00002.jpg
# 808
# EAD2020_semantic_00003.jpg
# 808
# EAD2020_semantic_00004.jpg
# 499
# EAD2020_semantic_00005.jpg
# 499
# EAD2020_semantic_00006.jpg
# 1079
# EAD2020_semantic_00007.jpg
# 512
# EAD2020_semantic_00008.jpg
# 256
# EAD2020_semantic_00009.jpg
# 256
# EAD2020_semantic_00010.jpg
# 512
# EAD2020_semantic_00011.jpg
# 512
# EAD2020_semantic_00012.jpg
# 512
# EAD2020_semantic_00013.jpg
# 512
# EAD2020_semantic_00014.jpg
# 512
# EAD2020_semantic_00015.jpg
# 512
# EAD2020_semantic_00016.jpg
# 512
# EAD2020_semantic_00017.jpg
# 512
# EAD2020_semantic_00018.jpg
# 512
# EAD2020_semantic_00019.jpg
# 512
# EAD2020_semantic_00020.jpg
# 512
# EAD2020_semantic_00021.jpg
# 512
# EAD2020_semantic_00022.jpg
# 512
# EAD2020_semantic_00023.jpg
# 512
# EAD2020_semantic_00024.jpg
# 512
# EAD2020_semantic_00025.jpg
# 512
# EAD2020_semantic_00026.jpg
# 512
# EAD2020_semantic_00027.jpg
# 512
# ...

# %%
from PIL import Image
import numpy as np
im= Image.open('/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/masks_ead2020/EAD2020_semantic_00000.tif')
imarray = np.array(im)
#imarray=np.fliplr(imarray)
imarray=np.rot90(imarray, k=3, axes=(0, 1))
img=Image.fromarray(imarray)
#img.save('/content/drive/My Drive/mini/augment /output2/newfile.tif',format=None)
plt.imshow(img)

# %%
from PIL import Image
import numpy as np
l=[]
for i in os.listdir('/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/masks_ead2020'):
    l.append(i)
l.sort()
for i in l:
  im= Image.open('/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/masks_ead2020/'+i)
  imarray = np.array(im)
  img = Image.fromarray(imarray)
  #vertical
  imarray1 = np.flipud(imarray)
  img1=Image.fromarray(imarray1)
  #90 of orig
  imarray2 = imarray=np.rot90(imarray, k=3, axes=(0, 1))
  img2 = Image.fromarray(imarray2)
  #lr of vertical
  imarray3 = np.fliplr(imarray1)
  img3 = Image.fromarray(imarray3)
  img.save('/content/drive/My Drive/mini/augment/output2/'+str(i)+'_0.tif',format=None)
  img1.save('/content/drive/My Drive/mini/augment/output2/'+str(i)+'_1.tif',format=None)
  img2.save('/content/drive/My Drive/mini/augment/output2/'+str(i)+'_2.tif',format=None)
  img3.save('/content/drive/My Drive/mini/augment/output2/'+str(i)+'_3.tif',format=None)

# %%
from PIL import Image
plt.imshow(Image.open('/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/images_ead2020/EAD2020_semantic_00003.jpg'))

# %%
#plt.imshow(Image.open('./train_rot/output/out7_8.png'))

# %%
#len(os.listdir('./train_pro/input/'))
# Out:
# 800

# %%
#PIL Processing

# %%
im = Image.open('/content/drive/My Drive/mini/augment/outputEAD2020_semantic_00003.jpg_1.png')

# %%
plt.imshow(im)

# %%
#im = cv2.imread('/home/nikamanth/Documents/map/train/input/satImage_001.png')
