# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
def rotateImage(image, angle):
  image_center = tuple(np.array(image.shape[1::-1]) / 2)
  rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
  result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
  return result

# %%
root = '/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/images_ead2020'

for i in sorted(os.listdir(root)):
    print(i)
    im = cv2.imread(root+'/'+i)
    im2 = cv2.flip(im, 0) 
    im4 = cv2.rotate(im, cv2.ROTATE_90_CLOCKWISE)
    im5 = cv2.rotate(im, cv2.ROTATE_180)
    print(len(im2))
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_1.png',im)
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_2.png',im2)
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_4.png',im4)
    cv2.imwrite('/content/drive/My Drive/mini/augment/output/'+str(i)+'_5.png',im5)

# %%
root = '/content/drive/My Drive/mini/endocv/ead2020_semantic_segmentation/ead2020_semantic_segmentation/masks_ead2020'

# os.listdir(root)

# %%
im = Image.open(root+'/EAD2020_semantic_00011.tif')

# %%
imarray = np.array(im)

# %%
imarray.shape
# Out:
# (512, 512)
